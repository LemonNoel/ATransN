# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

font = {"family" : "Times New Roman",
        "size"   : 14,
        "weight": "bold"}
plt.rc("font", **font)


colors = [(0.6509803921568628, 0.807843137254902, 0.8901960784313725),
 (0.12156862745098039, 0.47058823529411764, 0.7058823529411765),
 (0.6980392156862745, 0.8745098039215686, 0.5411764705882353),
 (0.2, 0.6274509803921569, 0.17254901960784313),
 (0.984313725490196, 0.6039215686274509, 0.6),
 (0.8901960784313725, 0.10196078431372549, 0.10980392156862745),
 (0.9921568627450981, 0.7490196078431373, 0.43529411764705883),
 (1.0, 0.4980392156862745, 0.0),
 (0.792156862745098, 0.6980392156862745, 0.8392156862745098),
 (0.41568627450980394, 0.23921568627450981, 0.6039215686274509),
 (1.0, 1.0, 0.6),
 (0.6941176470588235, 0.34901960784313724, 0.1568627450980392)]

# %%
X = np.arange(4)
width = 0.2

hit3_transe =   [0.262911, 0.453885, 0.256537, 0.330264]
hit3_distmult = [0.192293, 0.359705, 0.223809, 0.208810]
hit3_complex =  [0.139867, 0.322763, 0.281359, 0.250468]
hit3_rotate =   [0.266432, 0.422848, 0.233151, 0.335122]

hit3_transe_ctrans =   [0.270149, 0.457387, 0.30172, 0.341923]
hit3_distmult_ctrans = [0.233177, 0.372937, 0.305063, 0.252485]
hit3_complex_ctrans =  [0.198357, 0.355265, 0.278350, 0.281146]
hit3_rotate_ctrans =   [0.264085, 0.435216, 0.284329, 0.369766]

hit3_transe_atrans =   [0.337637, 0.45749, 0.345416, 0.423379]
hit3_distmult_atrans = [0.220462, 0.369977, 0.378293, 0.387609]
hit3_complex_atrans =  [0.256064, 0.352115, 0.444648, 0.496752]
hit3_rotate_atrans =   [0.303208, 0.447481, 0.253044, 0.354101]

# plt.subplot(2, 2, 1)
plt.figure(figsize=(5,6))
plt.bar(X-width, hit3_transe, width, label="TransE", color=colors[0], alpha=0.4)
plt.bar(X, hit3_transe_ctrans, width, label="CTransE", color=colors[1], alpha=0.5)
plt.bar(X+width, hit3_transe_atrans, width, label="ATransN (TransE)", color=colors[1])
plt.xticks(np.arange(4), ["CN3l (EN-DE)", "WK3l (EN-FR)", "DWY100k (DBP-YG)", "DWY100k (DBP-WD)"], rotation="15")
plt.yticks(np.arange(7) * 0.1, np.arange(7) * 10)
plt.xlabel("Dataset")
plt.ylabel("Hits@3 (%)")
plt.legend(loc="upper left")
plt.savefig("transe_hit3.pdf")
plt.show()

# plt.subplot(2, 2, 2)
plt.figure(figsize=(5,6))
plt.bar(X-width, hit3_distmult, width, label="DistMult", color=colors[2], alpha=0.4)
plt.bar(X, hit3_distmult_ctrans, width, label="CDistMult", color=colors[3], alpha=0.5)
plt.bar(X+width, hit3_distmult_atrans, width, label="ATransN (DistMult)", color=colors[3])
plt.xticks(np.arange(4), ["CN3l (EN-DE)", "WK3l (EN-FR)", "DWY100k (DBP-YG)", "DWY100k (DBP-WD)"], rotation="15")
plt.yticks(np.arange(7) * 0.1, np.arange(7) * 10)
plt.xlabel("Dataset")
plt.ylabel("Hits@3 (%)")
plt.legend(loc="upper left")
plt.savefig("distmult_hit3.pdf")
plt.show()

# plt.subplot(2, 2, 3)
plt.figure(figsize=(5,6))
plt.bar(X-width, hit3_complex, width, label="ComplEx", color=colors[4], alpha=0.4)
plt.bar(X, hit3_complex_ctrans, width, label="CComplEx", color=colors[5], alpha=0.5)
plt.bar(X+width, hit3_complex_atrans, width, label="ATransN (ComplEx)", color=colors[5])
plt.xticks(np.arange(4), ["CN3l (EN-DE)", "WK3l (EN-FR)", "DWY100k (DBP-YG)", "DWY100k (DBP-WD)"], rotation="15")
plt.yticks(np.arange(7) * 0.1, np.arange(7) * 10)
plt.xlabel("Dataset")
plt.ylabel("Hits@3 (%)")
plt.legend(loc="upper left")
plt.savefig("complex_hit3.pdf")
plt.show()

# plt.subplot(2, 2, 4)
plt.figure(figsize=(5,6))
plt.bar(X-width, hit3_rotate, width, label="RotatE", color=colors[6], alpha=0.4)
plt.bar(X, hit3_rotate_ctrans, width, label="CRotatE", color=colors[7], alpha=0.5)
plt.bar(X+width, hit3_rotate_atrans, width, label="ATransN (RotatE)", color=colors[7])
plt.xticks(np.arange(4), ["CN3l (EN-DE)", "WK3l (EN-FR)", "DWY100k (DBP-YG)", "DWY100k (DBP-WD)"], rotation="15")
plt.yticks(np.arange(7) * 0.1, np.arange(7) * 10)
plt.xlabel("Dataset")
plt.ylabel("Hits@3 (%)")
plt.legend(loc="upper left")
plt.savefig("rotate_hit3.pdf")
plt.show()

# %%
X = np.arange(4)
width = 0.2

mr_transe =   [910.205399, 432.431582, 2778.936316, 3148.56446]
mr_distmult = [1333.820227, 1202.805589, 11221.39252, 15968.93881]
mr_complex =  [1481.181142, 2079.398464, 19932.01847, 21977.85207]
mr_rotate =   [822.509585, 491.755825, 3593.751428, 3992.215556]

mr_transe_ctrans =   [892.794014, 438.49197, 3216.146117, 3070.941596]
mr_distmult_ctrans = [973.36385, 1109.410817, 7316.273624, 10136.0512]
mr_complex_ctrans =  [1383.416275, 1618.738841, 11756.28496, 16579.31979]
mr_rotate_ctrans =   [818.244327, 451.590663, 3521.631726, 4652.312237]

mr_transe_atrans =   [446.494131, 403.673075, 617.207428, 636.221845]
mr_distmult_atrans = [832.229656, 973.133979, 4333.227535, 6449.121365]
mr_complex_atrans =  [1043.062402, 1446.292488, 3130.529857, 4925.517359]
mr_rotate_atrans =   [492.976721, 445.483119, 1630.61628, 1354.013621]

# plt.subplot(2, 2, 1)
plt.figure(figsize=(5,6))
plt.bar(X-width, mr_transe, width, label="TransE", color=colors[0], alpha=0.4)
plt.bar(X, mr_transe_ctrans, width, label="CTransE", color=colors[1], alpha=0.5)
plt.bar(X+width, mr_transe_atrans, width, label="ATransN (TransE)", color=colors[1])
plt.xticks(np.arange(4), ["CN3l (EN-DE)", "WK3l (EN-FR)", "DYW100k (DBP-YG)", "DYW100k (DBP-WD)"], rotation="15")
plt.yticks(np.linspace(0, 4000, 6), np.linspace(0, 40, 6, dtype=np.int))
plt.xlabel("Dataset")
plt.ylabel("MR (x 100)")
plt.legend(loc="upper left")
plt.savefig("transe_mr.pdf")
plt.show()

# plt.subplot(2, 2, 2)
plt.figure(figsize=(5,6))
plt.bar(X-width, mr_distmult, width, label="DistMult", color=colors[2], alpha=0.4)
plt.bar(X, mr_distmult_ctrans, width, label="CDistMult", color=colors[3], alpha=0.5)
plt.bar(X+width, mr_distmult_atrans, width, label="ATransN (DistMult)", color=colors[3])
plt.xticks(np.arange(4), ["CN3l (EN-DE)", "WK3l (EN-FR)", "DWY100k (DBP-YG)", "DWY100k (DBP-WD)"], rotation="15")
plt.yticks(np.linspace(0, 16000, 5), np.linspace(0, 16, 5, dtype=np.int))
plt.xlabel("Dataset")
plt.ylabel("MR (x 100)")
plt.legend(loc="upper left")
plt.savefig("distmult_mr.pdf")
plt.show()

# plt.subplot(2, 2, 3)
plt.figure(figsize=(5,6))
plt.bar(X-width, mr_complex, width, label="ComplEx", color=colors[4], alpha=0.4)
plt.bar(X, mr_complex_ctrans, width, label="CComplEx", color=colors[5], alpha=0.5)
plt.bar(X+width, mr_complex_atrans, width, label="ATransN (ComplEx)", color=colors[5])
plt.xticks(np.arange(4), ["CN3l (EN-DE)", "WK3l (EN-FR)", "DWY100k (DBP-YG)", "DWY100k (DBP-WD)"], rotation="15")
plt.yticks(np.linspace(0, 27000, 7), np.linspace(0, 27, 7, dtype=np.int))
plt.xlabel("Dataset")
plt.ylabel("MR (x 100)")
plt.legend(loc="upper left")
plt.savefig("complex_mr.pdf")
plt.show()

# plt.subplot(2, 2, 4)
plt.figure(figsize=(5,6))
plt.bar(X-width, mr_rotate, width, label="RotatE", color=colors[6], alpha=0.4)
plt.bar(X, mr_rotate_ctrans, width, label="CRotatE", color=colors[7], alpha=0.5)
plt.bar(X+width, mr_rotate_atrans, width, label="ATransN (RotatE)", color=colors[7])
plt.xticks(np.arange(4), ["CN3l (EN-DE)", "WK3l (EN-FR)", "DWY100k (DBP-YG)", "DWY100k (DBP-WD)"], rotation="15")
plt.yticks(np.linspace(0, 5000, 6), np.linspace(0, 50, 6, dtype=np.int))
plt.xlabel("Dataset")
plt.ylabel("MR (x 100)")
plt.legend(loc="upper left")
plt.savefig("rotate_mr.pdf")
plt.show()

# %%
plt.figure(figsize=(16,6))

X = np.arange(4)
width = 0.15
transe = [0.263889, 0.433194, 0.256537, 0.330264]
alpha_0 = [0.270149, 0.438176, 0, 0]
beta_0 = [0.292449, 0.447232, 0, 0.373677]
no_trans = [0.269757, 0.428592, 0, 0.343461]
atransn = [0.326878, 0.452463, 0.315181, 0.380323]
plt.bar(X-width*2, transe, width, label="TransE", color=colors[1])
plt.bar(X-width, alpha_0, width, label="alpha=0", color=colors[3])
plt.bar(X, beta_0, width, label="beta=0", color=colors[5])
plt.bar(X+width, no_trans, width, label="w/o AAM", color=colors[7])
plt.bar(X+width*2, atransn, width, label="ATransN", color=colors[9])
plt.xticks(np.arange(5), ["CN3l (EN-DE)", "WK3l (EN-FR)", "DYW100k (YG)", "DYW100k (WD)", ""])
plt.ylabel("Hits@10")
plt.legend(loc="upper right")
plt.savefig("hits10.pdf")
plt.show()

# %%
mr_transe = np.array([5189.203218] * 5)
mr_transe_trans = np.array([4336.811751, 3568.592489, 2852.487972, 2015.29439, 1219.315372])
mr_transe_joint = np.array([4767.30543, 4130.273035, 3347.439072, 2308.688842, 1207.063057])

mrr_transe = np.array([0.176461] * 5)
mrr_transe_trans = np.array([0.19074, 0.2116, 0.245405, 0.28625, 0.356395])
mrr_transe_joint = np.array([0.214011, 0.243736, 0.288825, 0.34931, 0.416251])

hit3_transe = np.array([0.214819] * 5)
hit3_transe_trans = np.array([0.223387, 0.240463, 0.27164, 0.313881, 0.381106])
hit3_transe_joint = np.array([0.319952, 0.348512, 0.399361, 0.465468, 0.534052])

hit10_transe = np.array([0.366204] * 5)
hit10_transe_trans = np.array([0.389338, 0.417695, 0.463434, 0.519314, 0.609346])
hit10_transe_joint = np.array([0.41021, 0.447303, 0.507001, 0.579123, 0.669659])

# %%
plt.figure(figsize=(6,4))

X = np.array([20, 40, 60, 80, 100])


plt.plot(X, mr_transe, label="TransE", color=colors[1], marker="x")
plt.plot(X, mr_transe_trans, label="ATransN", color=colors[3], marker="x")
plt.plot(X, mr_transe_joint, label="TransE (joint)", color=colors[2], marker="x")


plt.xticks(X, X)
plt.xlabel("Overlap Ratio (%)")
plt.ylabel("MR")
plt.legend(loc="lower left")
plt.savefig("ablation_mr.pdf")
plt.show()

# %%
plt.figure(figsize=(6,4))

X = np.array([20, 40, 60, 80, 100])

plt.plot(X, mrr_transe, label="TransE", color=colors[4], marker="o")
plt.plot(X, mrr_transe_trans, label="ATransN", color=colors[5], marker="o")
plt.plot(X, mrr_transe_joint, label="TransE (joint)", color=colors[6], marker="o")


plt.xticks(X, X)
plt.xlabel("Overlap Ratio (%)")
plt.ylabel("MRR")
plt.legend(loc="upper left")
plt.savefig("ablation_mrr.pdf")
plt.show()

# %%
plt.figure(figsize=(6,4))

X = np.array([20, 40, 60, 80, 100])

plt.plot(X, hit3_transe*100, label="TransE", color=colors[7], marker="^")
plt.plot(X, hit3_transe_trans*100, label="ATransN", color=colors[9], marker="^")
plt.plot(X, hit3_transe_joint*100, label="TransE (joint)", color=colors[8], marker="^")


plt.xticks(X, X)
plt.xlabel("Overlap Ratio (%)")
plt.ylabel("Hits@3 (%)")
plt.legend(loc="upper left")
plt.savefig("ablation_hit3.pdf")
plt.show()

# %%
plt.figure(figsize=(6,4))

X = np.array([20, 40, 60, 80, 100])

plt.plot(X, hit10_transe*100, label="TransE", color=colors[7], marker="^")
plt.plot(X, hit10_transe_trans*100, label="ATransN", color=colors[9], marker="^")
plt.plot(X, hit10_transe_joint*100, label="TransE (joint)", color=colors[8], marker="^")


plt.xticks(X, X)
plt.xlabel("Overlap Ratio (%)")
plt.ylabel("Hits@10 (%)")
plt.legend(loc="upper left")
plt.savefig("ablation_hit10.pdf")
plt.show()

# %%
grad_mr = np.array(
"""
444.776589
438.3413
443.359031
443.217696
443.719542
441.099645
444.818968
445.944609
440.754037
438.49197
445.170731
444.958515
439.840084
439.800064
443.195627
442.373187
441.185355
444.593095
442.520413
442.670965
""".split(), dtype=np.float).reshape(5, 4).T

grad_mrr = np.array(
"""
0.418663
0.421785
0.42173
0.420481
0.422032
0.422231
0.421139
0.421572
0.423179
0.422052
0.421749
0.421423
0.422979
0.42194
0.421283
0.421261
0.421747
0.421548
0.421283
0.42104
""".split(), dtype=np.float).reshape(5, 4).T

grad_hit3 = np.array(
"""
0.453885
0.457167
0.455995
0.455365
0.457152
0.45664
0.457446
0.456244
0.45916
0.457475
0.456698
0.45683
0.457387
0.457856
0.455907
0.456156
0.457226
0.456464
0.456493
0.456669
""".split(), dtype=np.float).reshape(5, 4).T

grad_hit10 = np.array(
"""
0.588259
0.591102
0.591908
0.591791
0.590707
0.590941
0.592509
0.591894
0.590677
0.590956
0.591981
0.591234
0.589813
0.591527
0.591908
0.590355
0.590692
0.591908
0.590457
0.592231
""".split(), dtype=np.float).reshape(5, 4).T

# %%
plt.imshow(grad_mr[::-1, :], cmap='spring')
plt.xlabel("α")
plt.ylabel("β")
# plt.xticks(np.arange(6), ["0.0", "1.0", "5.0", "10.0", "20.0", "30.0"])
# plt.yticks(np.arange(5), ["0.0", "0.1", "0.2", "0.4", "0.8"][::-1])
plt.xticks(np.arange(5), ["0.0", "0.1", "0.2", "0.4", "0.8"])
plt.yticks(np.arange(4), ["0.0", "0.1", "0.2", "0.4"][::-1])
cb = plt.colorbar()
# cb.set_ticks([400, 500, 600, 700, 800, 900, 1000])
# cb.set_ticklabels(["400", "500", "600", "700", "800", "900", "1000"])
plt.savefig("grad_wk3l_c_mr.pdf")
plt.show()

plt.imshow(grad_mrr[::-1, :], cmap='summer')
plt.xlabel("α")
plt.ylabel("β")
# plt.xticks(np.arange(6), ["0.0", "1.0", "5.0", "10.0", "20.0", "30.0"])
# plt.yticks(np.arange(5), ["0.0", "0.1", "0.2", "0.4", "0.8"][::-1])
plt.xticks(np.arange(5), ["0.0", "0.1", "0.2", "0.4", "0.8"])
plt.yticks(np.arange(4), ["0.0", "0.1", "0.2", "0.4"][::-1])
cb = plt.colorbar()
# cb.set_ticks([0.15, 0.16, 0.17, 0.18, 0.19, 0.20])
# cb.set_ticklabels(["0.15", "0.16", "0.17", "0.18", "0.19", "0.20"])
plt.savefig("grad_wk3l_c_mrr.pdf")
plt.show()

plt.imshow(grad_hit3[::-1, :], cmap='autumn')
plt.xlabel("α")
plt.ylabel("β")
# plt.xticks(np.arange(6), ["0.0", "1.0", "5.0", "10.0", "20.0", "30.0"])
# plt.yticks(np.arange(5), ["0.0", "0.1", "0.2", "0.4", "0.8"][::-1])
plt.xticks(np.arange(5), ["0.0", "0.1", "0.2", "0.4", "0.8"])
plt.yticks(np.arange(4), ["0.0", "0.1", "0.2", "0.4"][::-1])
cb = plt.colorbar()
# cb.set_ticks([0.27, 0.28, 0.29, 0.30, 0.31, 0.32, 0.33, 0.34])
# cb.set_ticklabels(["0.27", "0.28", "0.29", "0.30", "0.31", "0.32", "0.33", "0.34"])
# cb.set_ticks([0.4530, 0.4550, 0.4570, 0.4590])
# cb.set_ticklabels(["0.4530", "0.4560", "0.4570", "0.4590"])
plt.savefig("grad_wk3l_c_hit3.pdf")
plt.show()

plt.imshow(grad_hit10[::-1, :], cmap='winter')
plt.xlabel("α")
plt.ylabel("β")
# plt.xticks(np.arange(6), ["0.0", "1.0", "5.0", "10.0", "20.0", "30.0"])
# plt.yticks(np.arange(5), ["0.0", "0.1", "0.2", "0.4", "0.8"][::-1])
plt.xticks(np.arange(5), ["0.0", "0.1", "0.2", "0.4", "0.8"])
plt.yticks(np.arange(4), ["0.0", "0.1", "0.2", "0.4"][::-1])
cb = plt.colorbar()
# cb.set_ticks([0.34, 0.36, 0.38, 0.40, 0.42, 0.44, 0.46])
# cb.set_ticklabels(["0.34", "0.36", "0.38", "0.40", "0.42", "0.44", "0.46"])
# cb.set_ticks([0.5890, 0.5900, 0.5910, 0.5920, 5930])
# cb.set_ticklabels(["0.5890", "0.5800", "0.5910", "0.5920", "0.5930"])
plt.savefig("grad_wk3l_c_hit10.pdf")
plt.show()

# %%
grad_mr[0]
# Out:
# array([431.576463, 410.684696, 393.348642, 398.374139, 401.738651])
